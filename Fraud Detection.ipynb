# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sc
import matplotlib

#imorting system
import sys

# %%
print('Python version = {}'.format(sys.version))
print('Numpy version = {}'.format(np.__version__))
print('Pandas version = {}'.format(pd.__version__))
print('Matplotlib version = {}'.format(matplotlib.__version__))
print('Seaborn version = {}'.format(sns.__version__))
# Out:
# Python version = 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
# Numpy version = 1.14.0
# Pandas version = 0.22.0
# Matplotlib version = 2.1.2
# Seaborn version = 0.8.1

# %%
#loading dataset
data= pd.read_csv(r'C:\Users\user-pc\Machine learning\Fraud detection\creditcardfraud\creditcard.csv')
pd.options.display.max_columns=None

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data.columns
#there must be too many columns but the bank doesnot want to display their customers data so they give us data after dim reduction.
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.describe(include='all')
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
#Taking a sample of data to process
data1 = data.sample(frac=0.1, random_state=1)
print(data1.shape)
# Out:
# (28481, 31)

# %%
#Plot histogram of each parameter
data.hist(figsize=(15,10))
plt.show()

# %%
#Low number of fraudulent transaction
data.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
fraud= data1.loc[data1["Class"]==1]
valid= data1.loc[data1["Class"]==0]

fraud_fraction= float(len(fraud))/float(len(valid))
print('fraud_fraction = {}'.format(fraud_fraction))

print('Fraud cases = {}'.format(len(fraud)))
print('Valid cases = {}'.format(len(valid)))
# Out:
# fraud_fraction = 0.0017234102419808666
# Fraud cases = 49
# Valid cases = 28432

# %%
#corelation matrix
corr= data.corr()
corr
plt.figure(figsize=(10,8))
sns.heatmap(data=corr, annot=False, linecolor='black', linewidths=0.1,cmap="YlGnBu",)

# %%
relation = pd.Series(data=corr['Class'].sort_values(ascending=False))
relation
# Out:
# Class     1.000000
# V11       0.154876
# V4        0.133447
# V2        0.091289
# V21       0.040413
# V19       0.034783
# V20       0.020090
# V8        0.019875
# V27       0.017580
# V28       0.009536
# Amount    0.005632
# V26       0.004455
# V25       0.003308
# V22       0.000805
# V23      -0.002685
# V15      -0.004223
# V13      -0.004570
# V24      -0.007221
# Time     -0.012323
# V6       -0.043643
# V5       -0.094974
# V9       -0.097733
# V1       -0.101347
# V18      -0.111485
# V7       -0.187257
# V3       -0.192961
# V16      -0.196539
# V10      -0.216883
# V12      -0.260593
# V14      -0.302544
# V17      -0.326481
# Name: Class, dtype: float64

# %%
X= data1.iloc[:,:-1]
Y=data1.iloc[:,-1]

print(X.shape)
print(Y.shape)
# Out:
# (28481, 30)
# (28481,)

# %%
#taking care of missiong data
data1.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import SVC

# %%
#splitting the dataset into train and test
from sklearn.cross_validation import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=0.25, random_state=1)

# %%
#defining the outlier detection algorithm
#by default we take k value as 20
classifiers={'IsolationForest':IsolationForest(max_samples=len(X), contamination=fraud_fraction, random_state=1),
             'LocalOutlierFactor': LocalOutlierFactor(n_neighbors=20, contamination=fraud_fraction)}

# %%
#Fitting the model
for i, (clf_name, clf) in enumerate(classifiers.items()):
    if clf_name=="LocalOutlierFactor":
        y_pred= clf.fit_predict(X)
        scores_pred= clf.negative_outlier_factor_
    else:
        clf.fit(X)
        scores_pred= clf.decision_function(X)
        y_pred= clf.predict(X)
    
    y_pred[y_pred==1]=0
    y_pred[y_pred==-1]=1
    
    n_errors= (y_pred!=Y).sum()
    
    print("{} : {}".format(clf_name, n_errors))
    print(accuracy_score(Y, y_pred))
    print(classification_report(Y, y_pred)) 
    print(confusion_matrix(Y, y_pred))
    print('\n')
# Out:
# IsolationForest : 71
# 0.99750711000316
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     28432
#           1       0.28      0.29      0.28        49
#
# avg / total       1.00      1.00      1.00     28481
#
# [[28396    36]
#  [   35    14]]
#
#
# LocalOutlierFactor : 97
# 0.9965942207085425
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     28432
#           1       0.02      0.02      0.02        49
#
# avg / total       1.00      1.00      1.00     28481
#
# [[28383    49]
#  [   48     1]]
